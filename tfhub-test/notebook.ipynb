# %%
# !python --version
# !pip install tensorflow matplotlib
# Out:
# unknown option --version
# usage: python [option] ... [-c cmd | -m mod | file | -] [arg] ...
# Try `python -h' for more information.
# Collecting tensorflow
#   Downloading https://files.pythonhosted.org/packages/1d/56/0dbdae2a3c527a119bec0d5cf441655fe030ce1daa6fa6b9542f7dbd8664/tensorflow-2.1.0-cp37-cp37m-manylinux2010_x86_64.whl (421.8MB)
# Killed  |████████████████████████████████| 421.8MB 29.5MB/s eta 0:00:01

# %%
import matplotlib.pylab as plt
# !pip install -q tf-nightly
import tensorflow as tf
# Out:
# Killed
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-9d300a3a8ace> in <module>
#       1 import matplotlib.pylab as plt
#       2 get_ipython().system('pip install -q tf-nightly\r')
# ----> 3 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !pip install -q -U tf-hub-nightly
# !pip install -q tfds-nightly
import tensorflow_hub as hub

from tensorflow.keras import layers

# %%
classifier_url ="https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/2"
